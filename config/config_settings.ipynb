# %%
"""
Configurações do Projeto LGPD Healthcare Lakehouse
"""

# Storage Account
STORAGE_ACCOUNT = "mystoacc"

# Containers
LANDING_CONTAINER = "landing"
BRONZE_CONTAINER = "bronze"
SILVER_CONTAINER = "silver"
GOLD_CONTAINER = "gold"

# Paths
LANDING_PATH = f"abfss://{LANDING_CONTAINER}@{STORAGE_ACCOUNT}.dfs.core.windows.net"
BRONZE_PATH = f"abfss://{BRONZE_CONTAINER}@{STORAGE_ACCOUNT}.dfs.core.windows.net"
SILVER_PATH = f"abfss://{SILVER_CONTAINER}@{STORAGE_ACCOUNT}.dfs.core.windows.net"
GOLD_PATH = f"abfss://{GOLD_CONTAINER}@{STORAGE_ACCOUNT}.dfs.core.windows.net"

# Databases
BRONZE_DATABASE = "healthcare_bronze"
SILVER_DATABASE = "healthcare_silver"
GOLD_DATABASE = "healthcare_gold"

# Tabelas
DIMENSIONS = [
    "dim_data",
    "dim_clinica",
    "dim_medico",
    "dim_diagnostico",
    "dim_exame",
    "dim_paciente"
]

FACTS = [
    "fato_consultas"
]

PII_TABLES = [
    "pii_paciente_identidade",
    "pii_medico_identidade"
]

# Chaves primárias
PRIMARY_KEYS = {
    "dim_data": ["sk_data"],
    "dim_clinica": ["sk_clinica"],
    "dim_medico": ["sk_medico"],
    "dim_diagnostico": ["sk_diagnostico"],
    "dim_exame": ["sk_exame"],
    "dim_paciente": ["sk_paciente"],
    "fato_consultas": ["id_consulta"],
    "pii_paciente_identidade": ["token_paciente"],
    "pii_medico_identidade": ["token_medico"]
}
